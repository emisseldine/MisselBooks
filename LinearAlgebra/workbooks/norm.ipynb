# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/MisselBooks/blob/main/LinearAlgebra/workbooks/norm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # 1.4 Norms
# </center>
#
# ###For Exercises 1-6 below, compute the norms and distances.
#
#
# ---
#
#
# *An example is provided in Exercise 0. To execute your code, hit the play/execute/run button or Shift+Enter.*

# %% [markdown]
# 0.   Compute $\left\Vert\left[\begin{array}{r}3\\-1\\5\end{array}\right]\right\Vert$.

# %%
import numpy as np

print(np.linalg.norm([3,-1,5]))
# Out:
# 5.916079783099616

# %% [markdown]
# 1.   Compute $\left\Vert\left[\begin{array}{r}7\\1\\5\end{array}\right]\right\Vert$.

# %%
### EXERCISE 1#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# np.linalg.norm([7,1,5])
# ```
#
# $5\sqrt{3}$
#
# </details>

# %% [markdown]
# 2.   Compute the norm of $\left[\begin{array}{r}2\\1\\-3\\2\end{array}\right]$.

# %%
### EXERCISE 2#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $3\sqrt{2}$
#
# </details>

# %% [markdown]
# 3.   Compute $\text{dist}\left(\left[\begin{array}{r}1\\1\\1\end{array}\right],\left[\begin{array}{r}5\\2\\2\end{array}\right]\right)$.

# %%
### EXERCISE 3#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $3\sqrt{2}$
#
# </details>

# %% [markdown]
# 4.   Compute the distance between $\left[\begin{array}{r}1\\-2\\1\end{array}\right]-\left[\begin{array}{r}0\\-5\\3\end{array}\right]$ and $2\left[\begin{array}{r}3\\-1\\-2\end{array}\right]+\left[\begin{array}{r}0\\1\\0\end{array}\right]$.

# %%
### EXERCISE 4#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $3\sqrt{5}$
#
# </details>

# %% [markdown]
# 5.  Compute the norm of the vectors $\boldsymbol{x}$ and $\boldsymbol{y}$, given the vectors $\boldsymbol{x}$ and $\boldsymbol{y}$ below.

# %%
### EXERCISE 5#######################################
x = np.array([ 5.68926168, 6.48028365, 5.64919868, 4.64594575, 9.70900398, 8.2673083, 1.48566455, 9.48149181, 0.30697194, 8.19313516])
y= np.array([ 4.12159476, -0.90500151, -1.24963052, -4.18992406, 5.47895589, 6.658136, -4.20026454, -7.38517255, -2.03795684, -6.02101768])
print("x =", x)
print("y =", y)

print("||x|| =", ) #compute the number here.
print("||y|| =", ) #compute the number here.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# ||x|| = 21.20850675359146
# ||y|| = 14.96202732208226
# ```
#
# </details>

# %% [markdown]
# 6.  Compute the mean, the RMS, and standard deviation for the vector $\boldsymbol{x}$ given below.

# %%
### EXERCISE 5#######################################
x = np.array([67.62205015, 18.85856747, 89.87482278, 33.23317543, 67.85376642, -7.76168227, 32.4542289, -5.69862975, 71.17102728, 22.10567789, 6.15236876, 80.30186233, 63.52505289, 46.06165362, 18.30431459, 82.95936131, 31.25160879, 34.81357958, 24.1450134, 56.96792735, 50.38486339, 62.0442239, 5.38461851, 19.41416245, 41.11320126, -5.09183741, 90.80877811, 72.99345778, 99.17639035, 72.66443221])

print("avg(x) = ", ) #compute the stats here.
print("rms(x) = ", )
print("std(x) = ", )

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# avg(x) = 44.769601249
# rms(x) = 54.3116465166349
# std(x) = 30.747971499815034
# ```
#
# </details>

# %% [markdown]
# ---
# *When completed, convert your .ipynb notebook into an .html webpage and upload it to the course's learning management system, e.g. Canvas.*
# <details><summary> Instructions to convert to .html </summary>
#
# 1. *Download the .ipynb notebook, which you want to convert, on your local computer.*
# 2. *Run the code below to upload the .ipynb notebook.*
# 3. *The .html webpage will be downloaded automatically on your local machine.*
#
# </details>

# %%
from google.colab import files
f = files.upload()
import subprocess
file0 = list(f.keys())[0]
_ = subprocess.run(["pip", "install", "nbconvert"])
_ = subprocess.run(["jupyter", "nbconvert", file0, "--to", "html"])
files.download(file0[:-5]+"html")

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/MisselBooks/tree/main/LinearAlgebra) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
