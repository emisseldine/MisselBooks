# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/MisselBooks/blob/main/LinearAlgebra/workbooks/column.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # 2.6 Matrix Equations
# </center>
#
# ###For Exercise 1 below, compute the matrix-vector product.
#
#
# ---
#
#
# *An example is provided in Exercise 0. To execute your code, hit the play/execute/run button or Shift+Enter.*

# %% [markdown]
# 0. $\begin{bmatrix} 4&5&2\\0&-1&3\\2&1&1\end{bmatrix}\begin{bmatrix} 1\\4\\3\end{bmatrix}$

# %%
import numpy as np

A = np.array([[4,5,2],
              [0,-1,3],
              [2,1,1]])
x = np.array([1,4,3])

print(A@x)
# Out:
# [30  5  9]

# %% [markdown]
# 1. $\begin{bmatrix}3&-1&2\\4&3&7\\-2&1&5\end{bmatrix}\begin{bmatrix}2\\-3\\1\end{bmatrix}$

# %%
### EXERCISE 1#######################################
A = np.array([[3,-1,2],
              [4,3,7],
              [-2,1,5]])
x = np.array([2,-3,1])

print('solution') #compute the matrix-vector product here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $\begin{bmatrix} 11\\6\\-2\end{bmatrix}$
#
# </details>

# %% [markdown]
# ---
#
# ###For Exercise 2 below, express the given matrix equation as a system of linear equations. Write the linear system as best you can with your keyboard and print it to screen.

# %% [markdown]
# 2. $\begin{bmatrix}1&2\\3&4\\-1&-2\\4&5\end{bmatrix}\begin{bmatrix}x\\y\end{bmatrix} = \begin{bmatrix} 2\\0\\2\\-9\end{bmatrix}$

# %%
### EXERCISE 2#######################################
print('solution') #write the linear system here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $\begin{cases}
# \hfill x &+\ 2y &=2\\
# \hfill3x &+\ 4y &= 0\\
# \hfill-x &-\ 2y &= 2\\
# \hfill 4x &+\ 5y &=-9
# \end{cases}$
#
# </details>

# %% [markdown]
# ---
#
# ###For Exercises 3-4 below, solve the matrix equation.

# %% [markdown]
# 3. $\begin{bmatrix}4&4&2\\-4&-3&-2\\-4&-3&1\end{bmatrix}\begin{bmatrix}x_1\\x_2\\x_3\end{bmatrix} = \begin{bmatrix}12\\-3\\3\end{bmatrix}$

# %%
### EXERCISE 3#######################################
A = np.array([[4,4,2],
              [-4,-3,-2],
              [-4,-3,1]])
b = np.array([12,-3,3])

print('solution') #solve matrix equation here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $\begin{bmatrix} -7\\9\\2\end{bmatrix}$
#
# </details>

# %% [markdown]
# 4. $\begin{bmatrix}1&0\\2&5\\3&-2\end{bmatrix}\begin{bmatrix}x_1\\x_2\end{bmatrix}=\begin{bmatrix}1\\3\\0\end{bmatrix}$

# %%
### EXERCISE 4#######################################
A = np.array([[1,0],
              [2,5],
              [3,-2]])
b = np.array([1,3,0])

print('solution') #solve matrix equation here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# inconsistent
#
# </details>

# %% [markdown]
# ---
#
# ### For Exercises 5-6, use the transformation $T:\mathbb{R}^4\to \mathbb{R}^2$ given by the rule:
# $$T(x_1,x_2,x_3,x_4)=\begin{bmatrix}2&-1&0&3 \\ 0&6&-2&1\end{bmatrix}\begin{bmatrix}x_1\\x_2\\x_3\\x_4\end{bmatrix}$$

# %% [markdown]
# 5. Compute $T(1, 0, 0, 1)$ and $T(1, 2, 3, 4)$.

# %%
### EXERCISE 5#######################################
A = np.array([[2,-1,0,3],
              [0,6,-2,1]])
x = np.array([1,0,0,1])
y = np.array([1,2,3,4])

print(f'T(x) = {'solution'}, T(y) = {'solution'}') #evaluate linear transformation here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $T(1,0,0,1) =(5,1)$,
#
# $T(1,2,3,4) = (12,10)$
#
# </details>

# %% [markdown]
# 6. Find $\boldsymbol x$ such that $T(\boldsymbol x) = (1,2)$.

# %%
### EXERCISE 6#######################################
b = np.array([1,2])

x = #find x such that T(x) = (1,2)

print(f'x = {x}, note that T(x) = {A@x}') #report solution here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# Answers may vary but $T(\boldsymbol x)$ should always equal (1,2),
#
# e.g. $\boldsymbol x= (2/3, 1/3, 0, 0)$
#
# </details>

# %% [markdown]
# 7.  Suppose we are a trader of currencies, e.g. US dollar, Euro, Korean won, Japanese yen, and we work with $n$ different currencies. At a given time, let the vector $\boldsymbol x$ be our portfolio of amount holdings in each of the $n$ currencies, that is, $x_i$ is the current value we hold in currency $i$. Let $A$ be an $n\times n$ matrix where $a_{ij}$ is the exchange rate for exchanging currency $j$ into currency $i$, that is, $a_{ij}$ is the amount of currency $i$ we would have if we exchange one note of currency $j$ into currency $i$. This includes any fees associated with the exchange, that is, $a_{ji}a_{ij} < 1$. Note that $a_{ii}=1$, that is, there is no change when a currency is no exchanged. Interpret the meaning for $A\boldsymbol x$.

# %%
### EXERCISE 7#######################################
print('Answer here')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# Each entry $x_i$ would be the total value if we converted all notes into currency $i$.
#
# </details>

# %% [markdown]
# ---
# *When completed, convert your .ipynb notebook into an .html webpage and upload it to the course's learning management system, e.g. Canvas.*
# <details><summary> Instructions to convert to .html </summary>
#
# 1. *Download the .ipynb notebook, which you want to convert, on your local computer.*
# 2. *Run the code below to upload the .ipynb notebook.*
# 3. *The .html webpage will be downloaded automatically on your local machine.*
#
# </details>

# %%
from google.colab import files
f = files.upload()
import subprocess
file0 = list(f.keys())[0]
_ = subprocess.run(["pip", "install", "nbconvert"])
_ = subprocess.run(["jupyter", "nbconvert", file0, "--to", "html"])
files.download(file0[:-5]+"html")

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/MisselBooks/tree/main/LinearAlgebra) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
